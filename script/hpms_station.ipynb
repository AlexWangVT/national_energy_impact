# %%
from pyspark.sql import SparkSession
from pyspark.conf import SparkConf
import psycopg2
import findspark
findspark.init()
findspark.find()
# Out:
# '/home/jwang/workspace/national_energy_impact/.venv/lib/python3.8/site-packages/pyspark'

# %%
spark = SparkSession.builder \
        .appName("Python Spark SQL basic example") \
        .config('spark.jars', '/home/jwang/workspace/postgresql_jar/postgresql-42.6.0.jar') \
        .getOrCreate()
# Out:
# 23/08/01 12:14:21 WARN Utils: Your hostname, jwang resolves to a loopback address: 127.0.1.1; using 192.168.2.168 instead (on interface wlp0s20f3)
# 23/08/01 12:14:21 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 23/08/01 12:14:21 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
def db_connect(host, database, user, password, port, schema, table_name):
    # prepare for saving data to postgresql
    # connect to postgresql database, create a schema if not exist, and clear old tables
    conn_string = 'postgresql://{0}:{1}@{2}:{3}/{4}'.format(user, password, host, port, database)
    pg_conn = psycopg2.connect(conn_string)
    cur = pg_conn.cursor()  
    cur.execute(f"CREATE SCHEMA IF NOT EXISTS {schema}")
    cur.execute(f"DROP TABLE IF EXISTS {schema}.{table_name}")
    pg_conn.commit()
    pg_conn.close()


def process_station_data_and_rename_columns(drop_cols, file_name):
    # station data from year of 2022 has mismatched column headers
    # will read and rename the headers to the correct ones, and drop unwanted columns
    station_df = spark.read.csv(file_name, sep='|', header=True)
    station_df = station_df.drop(*drop_cols)
    station = station_df.withColumnRenamed('Travel_Lane', 'Year_Record1')\
                       .withColumnRenamed('Travel_Dir', 'Travel_Lane')\
                       .withColumnRenamed('Station_Id', 'Travel_Dir')\
                       .withColumnRenamed('State_Code', 'Station_Id')\
                       .withColumnRenamed('Year_Record', 'State_Code')\
                       .withColumnRenamed('Year_Record1', 'Year_Record')
    return station 

def process_station_data(drop_cols, file_name):
    # read and drop unwanted columns
    station_df = spark.read.csv(file_name, sep='|', header=True)
    station = station_df.drop(*drop_cols)
    return station 


def load_data_to_postgres(df, schema, table_name, host, database, user, password, port):
    # save data frames into postgresql
    dbtable = f"{schema}.{table_name}"
    url = "jdbc:postgresql://{0}:{1}/{2}".format(host, port, database)
    df.write.format("jdbc")\
        .option('driver', 'org.postgresql.Driver') \
        .option("url", url).option('dbtable', dbtable) \
        .option("user", user).option("password", password).save()
    print("Add to postgresql: " + dbtable)

# %%
def process_station_data_without_seperator(drop_cols, file_name, station_data_size):
    # read station data from files that are not seperated by , or |
    # and drop unwanted columns
    sample_file_for_station_schema = "../HPMS_Data_Unified_Name/HPMS_Data_Unified_Name/2021/2021 (TMAS).STA"
    df = spark.read.csv(sample_file_for_station_schema, sep='|', header=True)
    columns = df.schema
    file = open(file_name, 'r', errors='ignore')
    lines = file.readlines()
    all_data = []
    for line in lines:
        new_row = []
        idx = 0
        for station_data in station_data_size:
            if station_data[1] > 0:
                new_row.append(line[idx: idx+station_data[1]])
                idx += station_data[1]
            else: # the last column 'Station_Location' has variable size
                new_row.append(line[idx:-1])
        all_data.append(new_row)
    file.close()
    station_df = spark.createDataFrame(data=all_data, schema=columns)
    station = station_df.drop(*drop_cols)
    return station

# %%
def main():
    host = 'localhost'
    database = 'national_volume_osm'
    user = 'postgres'
    password = 'wjh00813'
    port = 5432
    drop_cols = ('Sample_Type_Volume', 'Num_Lanes_Volume', 'Method_Volume', 'Sample_Type_Class',\
                'Num_Lanes_Class', 'Method_Class', 'Algorithm_Volume', 'Sample_Type_Truck', \
                'Num_Lanes_Truck', 'Method_Truck', 'Data_Retrieval', 'Primary_Purpose', \
                'LRS_Id', 'LRS_Point', 'SHRP_Id', 'Is_Sample', 'Sample_Id', 'Con_Route_Signing', \
                    'Con_Signed_Route')

    states_dict = {
            'AK': 'Alaska',
            'AL': 'Alabama',
            'AR': 'Arkansas',
            'AZ': 'Arizona',
            'CA': 'California',
            'CO': 'Colorado',
            'CT': 'Connecticut',
            'DC': 'District of Columbia',
            'DE': 'Delaware',
            'FL': 'Florida',
            'GA': 'Georgia',
            'HI': 'Hawaii',
            'IA': 'Iowa',
            'ID': 'Idaho',
            'IL': 'Illinois',
            'IN': 'Indiana',
            'KS': 'Kansas',
            'KY': 'Kentucky',
            'LA': 'Louisiana',
            'MA': 'Massachusetts',
            'MD': 'Maryland',
            'ME': 'Maine',
            'MI': 'Michigan',
            'MN': 'Minnesota',
            'MO': 'Missouri',
            'MS': 'Mississippi',
            'MT': 'Montana',
            'NC': 'North Carolina',
            'ND': 'North Dakota',
            'NE': 'Nebraska',
            'NH': 'New Hampshire',
            'NJ': 'New Jersey',
            'NM': 'New Mexico',
            'NV': 'Nevada',
            'NY': 'New York',
            'OH': 'Ohio',
            'OK': 'Oklahoma',
            'OR': 'Oregon',
            'PA': 'Pennsylvania',
            'RI': 'Rhode Island',
            'SC': 'South Carolina',
            'SD': 'South Dakota',
            'TN': 'Tennessee',
            'TX': 'Texas',
            'UT': 'Utah',
            'VA': 'Virginia',
            'VT': 'Vermont',
            'WA': 'Washington',
            'WI': 'Wisconsin',
            'WV': 'West Virginia',
            'WY': 'Wyoming'
    }
    station_data_size = (
        ('Record_Type',1),
        ('State_Code',2),
        ('Station_Id',6),
        ('Travel_Dir',1),
        ('Travel_Lane',1),
        ('Year_Record',2),
        ('F_System',2),
        ('Num_Lanes',1),
        ('Sample_Type_Volume',1),
        ('Num_Lanes_Volume',1),
        ('Method_Volume',1),
        ('Sample_Type_Class',1),
        ('Num_Lanes_Class',1),
        ('Method_Class',1),
        ('Algorithm_Volume',1),
        ('Num_Classes',2),
        ('Sample_Type_Truck',1),
        ('Num_Lanes_Truck',1),
        ('Method_Truck',1),
        ('Calibration',1),
        ('Data_Retrieval',1),
        ('Type_Sensor_1',1),
        ('Type_Sensor_2',1),
        ('Primary_Purpose',1),
        ('LRS_Id',12),
        ('LRS_Point',6),
        ('Latitude',8),
        ('Longitude',9),
        ('SHRP_Id',4),
        ('Prev_Station_Id',6),
        ('Year_Established',2),
        ('Year_Discontinued',2),
        ('County_Code',3),
        ('Is_Sample',1),
        ('Sample_Id',12),
        ('NHS',1),
        ('Posted_Route_Signing',1),
        ('Posted_Signed_Route',8),
        ('Con_Route_Signing',1),
        ('Con_Signed_Route',8),
        ('Station_Location',0)
    )
    states = list(states_dict.keys())
    months = ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec']
    schema_sta = 'station'
    state_code = spark.read.csv('state_code.csv', header=True)
    years = [i for i in range(2022, 2010, -1)]

    for year in years:
        if year in [2022, 2020, 2019, 2018]:
            # only for 2022, 2020, 2019, 2018
            sta_file_names = ["../HPMS_Data_Unified_Name/HPMS_Data_Unified_Name/{0}/{0}_station_data/{1}_{0} (TMAS).STA".format(year, state)\
                            for state in states]
            for file_name in sta_file_names:
                table_name = file_name.split('/')[5].split('.')[0].split(' ')[0]
                db_connect(host, database, user, password, port, schema_sta, table_name)
                if year == 2022:
                    station = process_station_data_and_rename_columns(drop_cols, file_name)
                else: # in [2020, 2019, 2018]
                    station = process_station_data_without_seperator(drop_cols, file_name, station_data_size)
                load_data_to_postgres(station, schema_sta, table_name, host, database, user, password, port)
        else:
            # only for 2021, 2017, 2016, 2015, 2014, 2013, 2012, 2011
            sta_file_names = ["../HPMS_Data_Unified_Name/HPMS_Data_Unified_Name/{0}/{0} (TMAS).STA".format(year)]
            for file_name in sta_file_names:
                if year == 2021:
                    all_station = process_station_data(drop_cols, file_name)
                else: # in [2017, 2016, 2015, 2014, 2013, 2012, 2011]
                    all_station = process_station_data_without_seperator(drop_cols, file_name, station_data_size)
                for state in states:
                    table_name = state + '_' + file_name.split('/')[4].split('.')[0].split(' ')[0]
                    db_connect(host, database, user, password, port, schema_sta, table_name)
                    code = state_code.filter(state_code.state == states_dict[state]).select('code').collect()[0][0]
                    station = all_station.filter(all_station.State_Code == code)
                    load_data_to_postgres(station, schema_sta, table_name, host, database, user, password, port)

# %%
if __name__ == "__main__":
    main()
# Out:
# 23/08/01 12:14:25 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# Add to postgresql: station.AK_2022
# Add to postgresql: station.AL_2022
# Add to postgresql: station.AR_2022
# Add to postgresql: station.AZ_2022
# Add to postgresql: station.CA_2022
# Add to postgresql: station.CO_2022
# Add to postgresql: station.CT_2022
# Add to postgresql: station.DC_2022
# Add to postgresql: station.DE_2022
# Add to postgresql: station.FL_2022
# Add to postgresql: station.GA_2022
# Add to postgresql: station.HI_2022
# Add to postgresql: station.IA_2022
# Add to postgresql: station.ID_2022
# Add to postgresql: station.IL_2022
# Add to postgresql: station.IN_2022
# Add to postgresql: station.KS_2022
# Add to postgresql: station.KY_2022
# Add to postgresql: station.LA_2022
# Add to postgresql: station.MA_2022
# Add to postgresql: station.MD_2022
# Add to postgresql: station.ME_2022
# Add to postgresql: station.MI_2022
# Add to postgresql: station.MN_2022
# Add to postgresql: station.MO_2022
# Add to postgresql: station.MS_2022
# Add to postgresql: station.MT_2022
# Add to postgresql: station.NC_2022
# Add to postgresql: station.ND_2022
# Add to postgresql: station.NE_2022
# Add to postgresql: station.NH_2022
# Add to postgresql: station.NJ_2022
# Add to postgresql: station.NM_2022
# Add to postgresql: station.NV_2022
# Add to postgresql: station.NY_2022
# Add to postgresql: station.OH_2022
# Add to postgresql: station.OK_2022
# Add to postgresql: station.OR_2022
# Add to postgresql: station.PA_2022
# Add to postgresql: station.RI_2022
# Add to postgresql: station.SC_2022
# Add to postgresql: station.SD_2022
# Add to postgresql: station.TN_2022
# Add to postgresql: station.TX_2022
# Add to postgresql: station.UT_2022
# Add to postgresql: station.VA_2022
# Add to postgresql: station.VT_2022
# Add to postgresql: station.WA_2022
# Add to postgresql: station.WI_2022
# Add to postgresql: station.WV_2022
# Add to postgresql: station.WY_2022
# Add to postgresql: station.AK_2021
# Add to postgresql: station.AL_2021
# Add to postgresql: station.AR_2021
# Add to postgresql: station.AZ_2021
# Add to postgresql: station.CA_2021
# Add to postgresql: station.CO_2021
# Add to postgresql: station.CT_2021
# Add to postgresql: station.DC_2021
# Add to postgresql: station.DE_2021
# Add to postgresql: station.FL_2021
# Add to postgresql: station.GA_2021
# Add to postgresql: station.HI_2021
# Add to postgresql: station.IA_2021
# Add to postgresql: station.ID_2021
# Add to postgresql: station.IL_2021
# Add to postgresql: station.IN_2021
# Add to postgresql: station.KS_2021
# Add to postgresql: station.KY_2021
# Add to postgresql: station.LA_2021
# Add to postgresql: station.MA_2021
# Add to postgresql: station.MD_2021
# Add to postgresql: station.ME_2021
# Add to postgresql: station.MI_2021
# Add to postgresql: station.MN_2021
# Add to postgresql: station.MO_2021
# Add to postgresql: station.MS_2021
# Add to postgresql: station.MT_2021
# Add to postgresql: station.NC_2021
# Add to postgresql: station.ND_2021
# Add to postgresql: station.NE_2021
# Add to postgresql: station.NH_2021
# Add to postgresql: station.NJ_2021
# Add to postgresql: station.NM_2021
# Add to postgresql: station.NV_2021
# Add to postgresql: station.NY_2021
# Add to postgresql: station.OH_2021
# Add to postgresql: station.OK_2021
# Add to postgresql: station.OR_2021
# Add to postgresql: station.PA_2021
# Add to postgresql: station.RI_2021
# Add to postgresql: station.SC_2021
# Add to postgresql: station.SD_2021
# Add to postgresql: station.TN_2021
# Add to postgresql: station.TX_2021
# Add to postgresql: station.UT_2021
# Add to postgresql: station.VA_2021
# Add to postgresql: station.VT_2021
# Add to postgresql: station.WA_2021
# Add to postgresql: station.WI_2021
# Add to postgresql: station.WV_2021
# Add to postgresql: station.WY_2021
# Add to postgresql: station.AK_2020
# Add to postgresql: station.AL_2020
# Add to postgresql: station.AR_2020
# Add to postgresql: station.AZ_2020
# Add to postgresql: station.CA_2020
# Add to postgresql: station.CO_2020
# Add to postgresql: station.CT_2020
# Add to postgresql: station.DC_2020
# Add to postgresql: station.DE_2020
# Add to postgresql: station.FL_2020
# Add to postgresql: station.GA_2020
# Add to postgresql: station.HI_2020
# Add to postgresql: station.IA_2020
# Add to postgresql: station.ID_2020
# Add to postgresql: station.IL_2020
# Add to postgresql: station.IN_2020
# Add to postgresql: station.KS_2020
# Add to postgresql: station.KY_2020
# Add to postgresql: station.LA_2020
# Add to postgresql: station.MA_2020
# Add to postgresql: station.MD_2020
# Add to postgresql: station.ME_2020
# Add to postgresql: station.MI_2020
# Add to postgresql: station.MN_2020
# Add to postgresql: station.MO_2020
# Add to postgresql: station.MS_2020
# Add to postgresql: station.MT_2020
# Add to postgresql: station.NC_2020
# Add to postgresql: station.ND_2020
# Add to postgresql: station.NE_2020
# Add to postgresql: station.NH_2020
# Add to postgresql: station.NJ_2020
# Add to postgresql: station.NM_2020
# Add to postgresql: station.NV_2020
# Add to postgresql: station.NY_2020
# Add to postgresql: station.OH_2020
# Add to postgresql: station.OK_2020
# Add to postgresql: station.OR_2020
# Add to postgresql: station.PA_2020
# Add to postgresql: station.RI_2020
# Add to postgresql: station.SC_2020
# Add to postgresql: station.SD_2020
# Add to postgresql: station.TN_2020
# Add to postgresql: station.TX_2020
# Add to postgresql: station.UT_2020
# Add to postgresql: station.VA_2020
# Add to postgresql: station.VT_2020
# Add to postgresql: station.WA_2020
# Add to postgresql: station.WI_2020
# Add to postgresql: station.WV_2020
# Add to postgresql: station.WY_2020
# Add to postgresql: station.AK_2019
# Add to postgresql: station.AL_2019
# Add to postgresql: station.AR_2019
# Add to postgresql: station.AZ_2019
# Add to postgresql: station.CA_2019
# Add to postgresql: station.CO_2019
# Add to postgresql: station.CT_2019
# Add to postgresql: station.DC_2019
# Add to postgresql: station.DE_2019
# Add to postgresql: station.FL_2019
# Add to postgresql: station.GA_2019
# Add to postgresql: station.HI_2019
# Add to postgresql: station.IA_2019
# Add to postgresql: station.ID_2019
# Add to postgresql: station.IL_2019
# Add to postgresql: station.IN_2019
# Add to postgresql: station.KS_2019
# Add to postgresql: station.KY_2019
# Add to postgresql: station.LA_2019
# Add to postgresql: station.MA_2019
# Add to postgresql: station.MD_2019
# Add to postgresql: station.ME_2019
# Add to postgresql: station.MI_2019
# Add to postgresql: station.MN_2019
# Add to postgresql: station.MO_2019
# Add to postgresql: station.MS_2019
# Add to postgresql: station.MT_2019
# Add to postgresql: station.NC_2019
# Add to postgresql: station.ND_2019
# Add to postgresql: station.NE_2019
# Add to postgresql: station.NH_2019
# Add to postgresql: station.NJ_2019
# Add to postgresql: station.NM_2019
# Add to postgresql: station.NV_2019
# Add to postgresql: station.NY_2019
# Add to postgresql: station.OH_2019
# Add to postgresql: station.OK_2019
# Add to postgresql: station.OR_2019
# Add to postgresql: station.PA_2019
# Add to postgresql: station.RI_2019
# Add to postgresql: station.SC_2019
# Add to postgresql: station.SD_2019
# Add to postgresql: station.TN_2019
# Add to postgresql: station.TX_2019
# Add to postgresql: station.UT_2019
# Add to postgresql: station.VA_2019
# Add to postgresql: station.VT_2019
# Add to postgresql: station.WA_2019
# Add to postgresql: station.WI_2019
# Add to postgresql: station.WV_2019
# Add to postgresql: station.WY_2019
# Add to postgresql: station.AK_2018
# Add to postgresql: station.AL_2018
# Add to postgresql: station.AR_2018
# Add to postgresql: station.AZ_2018
# Add to postgresql: station.CA_2018
# Add to postgresql: station.CO_2018
# Add to postgresql: station.CT_2018
# Add to postgresql: station.DC_2018
# Add to postgresql: station.DE_2018
# Add to postgresql: station.FL_2018
# Add to postgresql: station.GA_2018
# Add to postgresql: station.HI_2018
# Add to postgresql: station.IA_2018
# Add to postgresql: station.ID_2018
# Add to postgresql: station.IL_2018
# Add to postgresql: station.IN_2018
# Add to postgresql: station.KS_2018
# Add to postgresql: station.KY_2018
# Add to postgresql: station.LA_2018
# Add to postgresql: station.MA_2018
# Add to postgresql: station.MD_2018
# Add to postgresql: station.ME_2018
# Add to postgresql: station.MI_2018
# Add to postgresql: station.MN_2018
# Add to postgresql: station.MO_2018
# Add to postgresql: station.MS_2018
# Add to postgresql: station.MT_2018
# Add to postgresql: station.NC_2018
# Add to postgresql: station.ND_2018
# Add to postgresql: station.NE_2018
# Add to postgresql: station.NH_2018
# Add to postgresql: station.NJ_2018
# Add to postgresql: station.NM_2018
# Add to postgresql: station.NV_2018
# Add to postgresql: station.NY_2018
# Add to postgresql: station.OH_2018
# Add to postgresql: station.OK_2018
# Add to postgresql: station.OR_2018
# Add to postgresql: station.PA_2018
# Add to postgresql: station.RI_2018
# Add to postgresql: station.SC_2018
# Add to postgresql: station.SD_2018
# Add to postgresql: station.TN_2018
# Add to postgresql: station.TX_2018
# Add to postgresql: station.UT_2018
# Add to postgresql: station.VA_2018
# Add to postgresql: station.VT_2018
# Add to postgresql: station.WA_2018
# Add to postgresql: station.WI_2018
# Add to postgresql: station.WV_2018
# Add to postgresql: station.WY_2018
# Add to postgresql: station.AK_2017
# Add to postgresql: station.AL_2017
# Add to postgresql: station.AR_2017
# Add to postgresql: station.AZ_2017
# Add to postgresql: station.CA_2017
# Add to postgresql: station.CO_2017
# Add to postgresql: station.CT_2017
# Add to postgresql: station.DC_2017
# Add to postgresql: station.DE_2017
# Add to postgresql: station.FL_2017
# Add to postgresql: station.GA_2017
# Add to postgresql: station.HI_2017
# Add to postgresql: station.IA_2017
# Add to postgresql: station.ID_2017
# Add to postgresql: station.IL_2017
# Add to postgresql: station.IN_2017
# Add to postgresql: station.KS_2017
# Add to postgresql: station.KY_2017
# Add to postgresql: station.LA_2017
# Add to postgresql: station.MA_2017
# Add to postgresql: station.MD_2017
# Add to postgresql: station.ME_2017
# Add to postgresql: station.MI_2017
# Add to postgresql: station.MN_2017
# Add to postgresql: station.MO_2017
# Add to postgresql: station.MS_2017
# Add to postgresql: station.MT_2017
# Add to postgresql: station.NC_2017
# Add to postgresql: station.ND_2017
# Add to postgresql: station.NE_2017
# Add to postgresql: station.NH_2017
# Add to postgresql: station.NJ_2017
# Add to postgresql: station.NM_2017
# Add to postgresql: station.NV_2017
# Add to postgresql: station.NY_2017
# Add to postgresql: station.OH_2017
# Add to postgresql: station.OK_2017
# Add to postgresql: station.OR_2017
# Add to postgresql: station.PA_2017
# Add to postgresql: station.RI_2017
# Add to postgresql: station.SC_2017
# Add to postgresql: station.SD_2017
# Add to postgresql: station.TN_2017
# Add to postgresql: station.TX_2017
# Add to postgresql: station.UT_2017
# Add to postgresql: station.VA_2017
# Add to postgresql: station.VT_2017
# Add to postgresql: station.WA_2017
# Add to postgresql: station.WI_2017
# Add to postgresql: station.WV_2017
# Add to postgresql: station.WY_2017
# Add to postgresql: station.AK_2016
# Add to postgresql: station.AL_2016
# Add to postgresql: station.AR_2016
# Add to postgresql: station.AZ_2016
# Add to postgresql: station.CA_2016
# Add to postgresql: station.CO_2016
# Add to postgresql: station.CT_2016
# Add to postgresql: station.DC_2016
# Add to postgresql: station.DE_2016
# Add to postgresql: station.FL_2016
# Add to postgresql: station.GA_2016
# Add to postgresql: station.HI_2016
# Add to postgresql: station.IA_2016
# Add to postgresql: station.ID_2016
# Add to postgresql: station.IL_2016
# Add to postgresql: station.IN_2016
# Add to postgresql: station.KS_2016
# Add to postgresql: station.KY_2016
# Add to postgresql: station.LA_2016
# Add to postgresql: station.MA_2016
# Add to postgresql: station.MD_2016
# Add to postgresql: station.ME_2016
# Add to postgresql: station.MI_2016
# Add to postgresql: station.MN_2016
# Add to postgresql: station.MO_2016
# Add to postgresql: station.MS_2016
# Add to postgresql: station.MT_2016
# Add to postgresql: station.NC_2016
# Add to postgresql: station.ND_2016
# Add to postgresql: station.NE_2016
# Add to postgresql: station.NH_2016
# Add to postgresql: station.NJ_2016
# Add to postgresql: station.NM_2016
# Add to postgresql: station.NV_2016
# Add to postgresql: station.NY_2016
# Add to postgresql: station.OH_2016
# Add to postgresql: station.OK_2016
# Add to postgresql: station.OR_2016
# Add to postgresql: station.PA_2016
# Add to postgresql: station.RI_2016
# Add to postgresql: station.SC_2016
# Add to postgresql: station.SD_2016
# Add to postgresql: station.TN_2016
# Add to postgresql: station.TX_2016
# Add to postgresql: station.UT_2016
# Add to postgresql: station.VA_2016
# Add to postgresql: station.VT_2016
# Add to postgresql: station.WA_2016
# Add to postgresql: station.WI_2016
# Add to postgresql: station.WV_2016
# Add to postgresql: station.WY_2016
# Add to postgresql: station.AK_2015
# Add to postgresql: station.AL_2015
# Add to postgresql: station.AR_2015
# Add to postgresql: station.AZ_2015
# Add to postgresql: station.CA_2015
# Add to postgresql: station.CO_2015
# Add to postgresql: station.CT_2015
# Add to postgresql: station.DC_2015
# Add to postgresql: station.DE_2015
# Add to postgresql: station.FL_2015
# Add to postgresql: station.GA_2015
# Add to postgresql: station.HI_2015
# Add to postgresql: station.IA_2015
# Add to postgresql: station.ID_2015
# Add to postgresql: station.IL_2015
# Add to postgresql: station.IN_2015
# Add to postgresql: station.KS_2015
# Add to postgresql: station.KY_2015
# Add to postgresql: station.LA_2015
# Add to postgresql: station.MA_2015
# Add to postgresql: station.MD_2015
# Add to postgresql: station.ME_2015
# Add to postgresql: station.MI_2015
# Add to postgresql: station.MN_2015
# Add to postgresql: station.MO_2015
# Add to postgresql: station.MS_2015
# Add to postgresql: station.MT_2015
# Add to postgresql: station.NC_2015
# Add to postgresql: station.ND_2015
# Add to postgresql: station.NE_2015
# Add to postgresql: station.NH_2015
# Add to postgresql: station.NJ_2015
# Add to postgresql: station.NM_2015
# Add to postgresql: station.NV_2015
# Add to postgresql: station.NY_2015
# Add to postgresql: station.OH_2015
# Add to postgresql: station.OK_2015
# Add to postgresql: station.OR_2015
# Add to postgresql: station.PA_2015
# Add to postgresql: station.RI_2015
# Add to postgresql: station.SC_2015
# Add to postgresql: station.SD_2015
# Add to postgresql: station.TN_2015
# Add to postgresql: station.TX_2015
# Add to postgresql: station.UT_2015
# Add to postgresql: station.VA_2015
# Add to postgresql: station.VT_2015
# Add to postgresql: station.WA_2015
# Add to postgresql: station.WI_2015
# Add to postgresql: station.WV_2015
# Add to postgresql: station.WY_2015
# Add to postgresql: station.AK_2014
# Add to postgresql: station.AL_2014
# Add to postgresql: station.AR_2014
# Add to postgresql: station.AZ_2014
# Add to postgresql: station.CA_2014
# Add to postgresql: station.CO_2014
# Add to postgresql: station.CT_2014
# Add to postgresql: station.DC_2014
# Add to postgresql: station.DE_2014
# Add to postgresql: station.FL_2014
# Add to postgresql: station.GA_2014
# Add to postgresql: station.HI_2014
# Add to postgresql: station.IA_2014
# Add to postgresql: station.ID_2014
# Add to postgresql: station.IL_2014
# Add to postgresql: station.IN_2014
# Add to postgresql: station.KS_2014
# Add to postgresql: station.KY_2014
# Add to postgresql: station.LA_2014
# Add to postgresql: station.MA_2014
# Add to postgresql: station.MD_2014
# Add to postgresql: station.ME_2014
# Add to postgresql: station.MI_2014
# Add to postgresql: station.MN_2014
# Add to postgresql: station.MO_2014
# Add to postgresql: station.MS_2014
# Add to postgresql: station.MT_2014
# Add to postgresql: station.NC_2014
# Add to postgresql: station.ND_2014
# Add to postgresql: station.NE_2014
# Add to postgresql: station.NH_2014
# Add to postgresql: station.NJ_2014
# Add to postgresql: station.NM_2014
# Add to postgresql: station.NV_2014
# Add to postgresql: station.NY_2014
# Add to postgresql: station.OH_2014
# Add to postgresql: station.OK_2014
# Add to postgresql: station.OR_2014
# Add to postgresql: station.PA_2014
# Add to postgresql: station.RI_2014
# Add to postgresql: station.SC_2014
# Add to postgresql: station.SD_2014
# Add to postgresql: station.TN_2014
# Add to postgresql: station.TX_2014
# Add to postgresql: station.UT_2014
# Add to postgresql: station.VA_2014
# Add to postgresql: station.VT_2014
# Add to postgresql: station.WA_2014
# Add to postgresql: station.WI_2014
# Add to postgresql: station.WV_2014
# Add to postgresql: station.WY_2014
# Add to postgresql: station.AK_2013
# Add to postgresql: station.AL_2013
# Add to postgresql: station.AR_2013
# Add to postgresql: station.AZ_2013
# Add to postgresql: station.CA_2013
# Add to postgresql: station.CO_2013
# Add to postgresql: station.CT_2013
# Add to postgresql: station.DC_2013
# Add to postgresql: station.DE_2013
# Add to postgresql: station.FL_2013
# Add to postgresql: station.GA_2013
# Add to postgresql: station.HI_2013
# Add to postgresql: station.IA_2013
# Add to postgresql: station.ID_2013
# Add to postgresql: station.IL_2013
# Add to postgresql: station.IN_2013
# Add to postgresql: station.KS_2013
# Add to postgresql: station.KY_2013
# Add to postgresql: station.LA_2013
# Add to postgresql: station.MA_2013
# Add to postgresql: station.MD_2013
# Add to postgresql: station.ME_2013
# Add to postgresql: station.MI_2013
# Add to postgresql: station.MN_2013
# Add to postgresql: station.MO_2013
# Add to postgresql: station.MS_2013
# Add to postgresql: station.MT_2013
# Add to postgresql: station.NC_2013
# Add to postgresql: station.ND_2013
# Add to postgresql: station.NE_2013
# Add to postgresql: station.NH_2013
# Add to postgresql: station.NJ_2013
# Add to postgresql: station.NM_2013
# Add to postgresql: station.NV_2013
# Add to postgresql: station.NY_2013
# Add to postgresql: station.OH_2013
# Add to postgresql: station.OK_2013
# Add to postgresql: station.OR_2013
# Add to postgresql: station.PA_2013
# Add to postgresql: station.RI_2013
# Add to postgresql: station.SC_2013
# Add to postgresql: station.SD_2013
# Add to postgresql: station.TN_2013
# Add to postgresql: station.TX_2013
# Add to postgresql: station.UT_2013
# Add to postgresql: station.VA_2013
# Add to postgresql: station.VT_2013
# Add to postgresql: station.WA_2013
# Add to postgresql: station.WI_2013
# Add to postgresql: station.WV_2013
# Add to postgresql: station.WY_2013
# Add to postgresql: station.AK_2012
# Add to postgresql: station.AL_2012
# Add to postgresql: station.AR_2012
# Add to postgresql: station.AZ_2012
# Add to postgresql: station.CA_2012
# Add to postgresql: station.CO_2012
# Add to postgresql: station.CT_2012
# Add to postgresql: station.DC_2012
# Add to postgresql: station.DE_2012
# Add to postgresql: station.FL_2012
# Add to postgresql: station.GA_2012
# Add to postgresql: station.HI_2012
# Add to postgresql: station.IA_2012
# Add to postgresql: station.ID_2012
# Add to postgresql: station.IL_2012
# Add to postgresql: station.IN_2012
# Add to postgresql: station.KS_2012
# Add to postgresql: station.KY_2012
# Add to postgresql: station.LA_2012
# Add to postgresql: station.MA_2012
# Add to postgresql: station.MD_2012
# Add to postgresql: station.ME_2012
# Add to postgresql: station.MI_2012
# Add to postgresql: station.MN_2012
# Add to postgresql: station.MO_2012
# Add to postgresql: station.MS_2012
# Add to postgresql: station.MT_2012
# Add to postgresql: station.NC_2012
# Add to postgresql: station.ND_2012
# Add to postgresql: station.NE_2012
# Add to postgresql: station.NH_2012
# Add to postgresql: station.NJ_2012
# Add to postgresql: station.NM_2012
# Add to postgresql: station.NV_2012
# Add to postgresql: station.NY_2012
# Add to postgresql: station.OH_2012
# Add to postgresql: station.OK_2012
# Add to postgresql: station.OR_2012
# Add to postgresql: station.PA_2012
# Add to postgresql: station.RI_2012
# Add to postgresql: station.SC_2012
# Add to postgresql: station.SD_2012
# Add to postgresql: station.TN_2012
# Add to postgresql: station.TX_2012
# Add to postgresql: station.UT_2012
# Add to postgresql: station.VA_2012
# Add to postgresql: station.VT_2012
# Add to postgresql: station.WA_2012
# Add to postgresql: station.WI_2012
# Add to postgresql: station.WV_2012
# Add to postgresql: station.WY_2012
# Add to postgresql: station.AK_2011
# Add to postgresql: station.AL_2011
# Add to postgresql: station.AR_2011
# Add to postgresql: station.AZ_2011
# Add to postgresql: station.CA_2011
# Add to postgresql: station.CO_2011
# Add to postgresql: station.CT_2011
# Add to postgresql: station.DC_2011
# Add to postgresql: station.DE_2011
# Add to postgresql: station.FL_2011
# Add to postgresql: station.GA_2011
# Add to postgresql: station.HI_2011
# Add to postgresql: station.IA_2011
# Add to postgresql: station.ID_2011
# Add to postgresql: station.IL_2011
# Add to postgresql: station.IN_2011
# Add to postgresql: station.KS_2011
# Add to postgresql: station.KY_2011
# Add to postgresql: station.LA_2011
# Add to postgresql: station.MA_2011
# Add to postgresql: station.MD_2011
# Add to postgresql: station.ME_2011
# Add to postgresql: station.MI_2011
# Add to postgresql: station.MN_2011
# Add to postgresql: station.MO_2011
# Add to postgresql: station.MS_2011
# Add to postgresql: station.MT_2011
# Add to postgresql: station.NC_2011
# Add to postgresql: station.ND_2011
# Add to postgresql: station.NE_2011
# Add to postgresql: station.NH_2011
# Add to postgresql: station.NJ_2011
# Add to postgresql: station.NM_2011
# Add to postgresql: station.NV_2011
# Add to postgresql: station.NY_2011
# Add to postgresql: station.OH_2011
# Add to postgresql: station.OK_2011
# Add to postgresql: station.OR_2011
# Add to postgresql: station.PA_2011
# Add to postgresql: station.RI_2011
# Add to postgresql: station.SC_2011
# Add to postgresql: station.SD_2011
# Add to postgresql: station.TN_2011
# Add to postgresql: station.TX_2011
# Add to postgresql: station.UT_2011
# Add to postgresql: station.VA_2011
# Add to postgresql: station.VT_2011
# Add to postgresql: station.WA_2011
# Add to postgresql: station.WI_2011
# Add to postgresql: station.WV_2011
# Add to postgresql: station.WY_2011
